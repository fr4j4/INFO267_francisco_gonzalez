# %% [markdown]
# ### Notebook 1:  Clustering con K-means
# En este notebook vamos a implementar el algoritmo de clustering K-means en R. El objetivo es entender como funciona este algoritmo y  aprender a utilizarlo con un ejemplo simple. Se incluye además la estrategia para definir el número de grupos k. Al final se propone un ejercicio con nuevos datos, con el fin de aprender a utilizar el algoritmo.

# %%
library(cluster)
library(ggplot2)

#ruta datos
#lee datos del archivo de texto como una matriz. La primera #columna se utiliza como vector de nombres de las filas
datos <-read.table("milk1.dat",row.names=1,dec=".",header=TRUE)
summary(datos)
# Out:
#      WATER          PROTEIN            FAT           LACTOSE
#  Min.   :44.90   Min.   : 0.600   Min.   : 1.00   Min.   :0.000
#  1st Qu.:71.30   1st Qu.: 3.000   1st Qu.: 3.40   1st Qu.:2.700
#  Median :82.00   Median : 5.900   Median : 6.30   Median :4.700
#  Mean   :78.18   Mean   : 6.212   Mean   :10.31   Mean   :4.132
#  3rd Qu.:87.70   3rd Qu.: 9.700   3rd Qu.:13.10   3rd Qu.:5.600
#  Max.   :90.40   Max.   :12.300   Max.   :42.00   Max.   :6.900
#       ASH
#  Min.   :0.1000
#  1st Qu.:0.5300
#  Median :0.8000
#  Mean   :0.8632
#  3rd Qu.:1.1000
#  Max.   :2.3000

# %% [markdown]
# Ejercicio 1: describa los datos y discuta la pertinencia de realizar un análisis de clustering o agrupamiento

# %%
#ingresar valor de k0 
k0=3
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos,col=cl$cluster)
# Out:
# plot without title

# %% [markdown]
# **R:**<br>Los datos describen leches de distintas especies de animales, con valores de porcentaje de agua, proteinas, grasa, lactosa y ceniza (minerales).<br>
# Es pertinente para poder clasificar los datos y agruparlos en grupos que tengan características en común. Como no sabemos a priori cuales serán las categorías en las que se clasificarán, es pertinente utilizar este método de aprendizaje no supervisado para determinarlas.

# %% [markdown]
# Ejercicio 2: Interprete y comente los resultados obtenidos.

# %%
#Análisis de Componentes Principales para graficar los grupos obtenidos
#Calcula plano de componentes principales y grafica las observaciones con el número de su grupo
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#   Comp.1    Comp.2     Comp.3      Comp.4      Comp.5
# 1 -3.831081 -2.2408320  0.09790001 -0.02910750 -0.029457957
# 2  1.243827  0.0248324  0.07949783 -0.02299768  0.004865841
# 3 -1.748439  0.5834780 -0.20968076  0.06088255 -0.002705362
# K-means clustering with 3 clusters of sizes 2, 16, 7
#
# Cluster means:
#      WATER   PROTEIN      FAT  LACTOSE      ASH
# 1 45.65000 10.150000 38.45000 0.450000 0.690000
# 2 86.06250  4.275000  4.17500 5.118750 0.635625
# 3 69.47143  9.514286 16.28571 2.928571 1.432857
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#          2          2          2          2          2          2          2
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          2          2          2          2          2          2          2
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
#          2          2          3          3          3          3          3
#   REINDEER      WHALE       SEAL    DOLPHIN
#          3          3          1          1
#
# Within cluster sum of squares by cluster:
# [1]  27.1912 377.2215 299.9911
#  (between_SS / total_SS =  89.9 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title

# %% [markdown]
# **R:**<br>Se han clasificado los datos, obteniendo tres grupos o clústers.<br>
# - Grupo1: Tienen mucho porcentaje de grasa.
# - Grupo2: Tienen mas porcentaje de lactosa y agua.
# - Grupo3: Son los que contienen más porcentaje de proteínas y ceniza(minerales).

# %% [markdown]
# Ejercicio 3: Repita el procedimiento considerando 2 y 4 grupos. Discuta sus resultados.

# %%
k0=2
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
pairs(datos,col=cl$cluster)
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#   Comp.1    Comp.2      Comp.3      Comp.4      Comp.5
# 1  1.112848  0.06603277  0.09432454 -0.03162076  0.0008469003
# 2 -2.364801 -0.14031964 -0.20043965  0.06719411 -0.0017996632
# K-means clustering with 2 clusters of sizes 17, 8
#
# Cluster means:
#      WATER  PROTEIN       FAT  LACTOSE       ASH
# 1 85.48824 4.570588  4.488235 4.994118 0.6688235
# 2 62.66250 9.700000 22.675000 2.300000 1.2762500
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#          1          1          1          1          1          1          1
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          1          1          1          1          1          1          1
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
#          1          1          1          2          2          2          2
#   REINDEER      WHALE       SEAL    DOLPHIN
#          2          2          2          2
#
# Within cluster sum of squares by cluster:
# [1]  521.8994 1664.9235
#  (between_SS / total_SS =  68.8 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title
# plot without title

# %% [markdown]
# Se crean dos grupos o clusters:<br>
# Grupo1- Ceniza(minerales), proteina y grasa<br>
# Grupo2- Agua Lactosa<br>

# %%
k0=4
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
pairs(datos,col=cl$cluster)
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#   Comp.1      Comp.2     Comp.3       Comp.4      Comp.5
# 1 -1.87604083  0.5598512 -0.299886203  0.09929465  0.007419768
# 2  1.87606405 -0.2017241 -0.007713097  0.09635908 -0.003291286
# 3 -3.83108138 -2.2408320  0.097900012 -0.02910750 -0.029457957
# 4  0.02253818  0.4485425  0.240092595 -0.21444910  0.006758595
# K-means clustering with 4 clusters of sizes 6, 10, 2, 7
#
# Cluster means:
#      WATER   PROTEIN      FAT  LACTOSE       ASH
# 1 68.33333  9.550000 17.41667 2.916667 1.4716667
# 2 88.50000  2.570000  2.80000 5.680000 0.4850000
# 3 45.65000 10.150000 38.45000 0.450000 0.6900000
# 4 81.18571  7.428571  6.90000 4.014286 0.9314286
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#          2          2          2          2          2          2          2
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          4          4          4          4          2          2          4
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
#          2          4          4          1          1          1          1
#   REINDEER      WHALE       SEAL    DOLPHIN
#          1          1          3          3
#
# Within cluster sum of squares by cluster:
# [1] 191.74708  59.41225  27.19120  63.53491
#  (between_SS / total_SS =  95.1 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title
# plot without title

# %% [markdown]
# Se crean dos grupos o clusters:<br>
# Grupo1- Grasa<br>
# Grupo2- Proteínas y ceniza(minerales)<br>
# Grupo3- Agua y lactosa<br>
# Grupo4- Agua, lactosa y minerales<br>

# %%
#Estrategia para elegir K, el numero de grupos
#J suma cuadrado de las distancias por cada k utilizado
#K-means


J<-rep(0,20)
fin_iter<-20

max_k=15 #maximo numero de k a buscar
tolerancia=2 #tolerancia que debe cumplir para que sea considerado

min_p<-0
for (k in 1:fin_iter){
    cl<-kmeans(datos,k,iter.max=1000,nstart=10)
    J[k]<-cl$tot.withinss
    if(k == 2){
        p <- abs(J[k-1] - J[k])
#        print("primera pendiente")
#        print(p)
        min_p<-p
    }
    else if(k>2){
        p <- abs( J[k-1] - J[k] )
        if(p < min_p && k < max_k && p <=tolerancia){
            min_p<-p
            best_k <- k
        }
    }
    
     
}



plot(1:fin_iter,J,xlab="k",ylab="J",type="p",main="J v/s k en k-means",col=2)
# Out:
# Plot with title “J v/s k en k-means”

# %% [markdown]
# Ejercicio 4: de acuerdo al gráfico obtenido, cuál es el valor de K mas apropiado?
# Agregue código para automatizar este criterio.

# %% [markdown]
# El que presente una menor pendiente, considerando alguna tolerancia especificada.

# %%
print("mejor_k")
print(best_k)
# Out:
# [1] "mejor_k"
# [1] 12

# %% [markdown]
# Ejercicio 5: Realice un análisis de clustering con el conjunto de datos DatosUsoFacebook.csv
# Interprete sus resultados.

# %%
library(cluster)
library(ggplot2)

datos <-read.csv("DatosUsoFacebook.csv",header=TRUE,sep=";")

k0=5
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
pairs(datos,col=cl$cluster)
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
points(res2[,1:2],col=1:k0,pch=19)

J<-rep(0,50)
fin_iter<-50

p_min<-0
mejork<-0
continue<-1

for (k in 1:fin_iter){
    cl<-kmeans(datos,k,iter.max=1000,nstart=10)
    J[k]<-cl$tot.withinss
    if (k > 2 && continue == 1) {
        p<-J[k-1]-J[k]#pendiente actual
        print(p)
        if(p < p_min ) {
            p_min<-p 
            mejork<-k
            print(k)
        }
    }else if(k == 2){
        p_min<-J[k-1]-J[k]
    }
}

print("mejor_k")
print(mejork)
plot(1:fin_iter,J,xlab="k",ylab="J",type="p",main="J v/s k en k-means",col=2)
# Out:
#   Comp.1     Comp.2     Comp.3     Comp.4      Comp.5      Comp.6
# 1 -0.1090022 -0.3415751 -0.8973098  0.05152166 -0.84265618 -0.01733338
# 2 -2.2866043 -0.5046503  1.4941570 -0.58137009 -0.63495783 -0.14592343
# 3 -1.5206326 -1.1785067 -0.5818015  0.45002900  0.92342307 -0.24804113
# 4  2.2086006 -0.1343081  0.1526466  0.22960447  0.03032648 -0.25414270
# 5 -0.2227583  1.0391152  0.2920656 -0.24185633  0.31027099  0.36958889
#   Comp.7      Comp.8      Comp.9      Comp.10     Comp.11     Comp.12
# 1 -0.39793081 -0.11646172 -0.23121278  0.48005352 -0.06668463  0.116925880
# 2 -0.38629211 -0.56467309  0.11784074 -0.48226172  0.22297385 -0.271431044
# 3  0.50227140  0.01779897  0.15935736  0.04383675 -0.10518005  0.050225313
# 4 -0.08024659  0.01773680  0.11189547 -0.14030779  0.08246372 -0.014481297
# 5  0.21590221  0.23150681 -0.04209965 -0.08467445 -0.03937646 -0.006530614
#   Comp.13     Comp.14      Comp.15     Comp.16
# 1  0.19887167 -0.009479306  0.12021201  0.039770092
# 2  0.28878410  0.125138032 -0.13419139  0.011015890
# 3 -0.37230635  0.006828969 -0.03491091 -0.066012404
# 4 -0.13710948 -0.036232903 -0.02582328  0.009276016
# 5  0.05634637 -0.007529192 -0.00289968 -0.006627680
# K-means clustering with 5 clusters of sizes 39, 18, 27, 45, 58
#
# Cluster means:
#         R1       R2       R3       R4       R5       R6       R7       R8
# 1 2.025641 2.589744 2.871795 2.230769 1.512821 1.743590 2.102564 2.717949
# 2 2.055556 2.388889 1.555556 1.388889 1.000000 1.222222 1.611111 1.500000
# 3 2.037037 1.888889 1.777778 2.296296 1.111111 3.037037 2.518519 2.148148
# 4 2.933333 2.955556 3.044444 2.377778 1.666667 1.733333 2.777778 3.000000
# 5 3.017241 2.741379 2.517241 2.448276 1.206897 1.758621 2.413793 2.896552
#         R9      R10      R11      R12      R13      R14      R15      R16
# 1 1.358974 1.897436 3.487179 1.589744 3.435897 1.410256 1.564103 1.230769
# 2 1.277778 2.277778 3.777778 1.444444 1.666667 1.166667 1.444444 1.000000
# 3 1.259259 2.148148 3.555556 1.777778 2.703704 1.296296 1.333333 1.222222
# 4 1.711111 1.866667 2.644444 2.400000 2.622222 1.600000 2.400000 1.777778
# 5 1.241379 1.879310 3.362069 1.413793 1.844828 1.137931 1.551724 1.189655
#
# Clustering vector:
#   [1] 1 2 3 1 1 5 5 3 1 3 1 2 1 4 4 5 3 3 4 4 1 5 4 4 5 2 5 1 5 5 1 1 4 5 1 3 5
#  [38] 1 2 1 5 2 4 1 5 5 3 5 1 3 5 1 1 4 4 5 3 4 4 4 5 4 5 5 5 4 5 4 4 4 1 5 5 4
#  [75] 5 5 1 2 2 1 2 5 4 4 4 2 1 5 1 4 5 4 2 5 4 3 1 1 5 5 4 3 1 2 3 5 3 3 5 3 5
# [112] 4 1 1 3 3 5 2 5 5 1 5 5 5 2 5 5 4 3 1 1 1 4 2 4 4 4 4 3 1 5 2 3 5 1 5 4 5
# [149] 1 5 5 2 1 5 4 3 1 4 5 1 5 4 4 4 4 4 5 5 2 1 3 1 5 4 4 5 5 5 3 4 2 5 3 3 4
# [186] 3 3
#
# Within cluster sum of squares by cluster:
# [1] 259.6410 143.5556 153.5556 335.2889 330.5172
#  (between_SS / total_SS =  26.1 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title
# [1] 103.7095
# [1] 3
# [1] 78.56167
# [1] 4
# [1] 63.18165
# [1] 5
# [1] 54.52599
# [1] 6
# [1] 36.88869
# [1] 7
# [1] 36.4547
# [1] 8
# [1] 32.3177
# [1] 9
# [1] 24.64644
# [1] 10
# [1] 29.32376
# [1] 21.56277
# [1] 12
# [1] 24.03856
# [1] 19.05161
# [1] 14
# [1] 17.37006
# [1] 15
# [1] 19.85319
# [1] 19.82354
# [1] 17.72075
# [1] 16.41763
# [1] 19
# [1] 20.50789
# [1] 9.203231
# [1] 21
# [1] 17.88378
# [1] 13.13866
# [1] 22.55902
# [1] 15.83844
# Warning message:
# “did not converge in 1000 iterations”
# [1] 3.307892
# [1] 26
# [1] 18.10843
# [1] 15.74254
# [1] 15.57944
# [1] 5.555411
# [1] 19.77569
# [1] 9.040368
# [1] 10.47096
# [1] 11.789
# [1] 12.40794
# [1] 8.135631
# [1] 9.500083
# [1] 11.76762
# Warning message:
# “did not converge in 1000 iterations”
# [1] 9.981585
# [1] 8.854654
# [1] 8.506061
# [1] 9.385317
# [1] 15.67817
# [1] 3.379365
# Warning message:
# “did not converge in 1000 iterations”
# [1] 8.966667
# [1] 11.45476
# [1] 10.72381
# [1] 3.426587
# [1] 11.60794
# Warning message:
# “did not converge in 1000 iterations”Warning message:
# “did not converge in 1000 iterations”
# [1] 4.916667
# [1] "mejor_k"
# [1] 26
# plot without title
# Plot with title “J v/s k en k-means”

# %%
mejork
# Out:
# [1] 26

# %% [markdown]
# Existen elementos de 15 características, se agruparon en 5 clústers. Aunque según el análisis (agregando código) el mejor número es de 26 grupos.
# EL análisis de los datos es un poco complicado, ya que son muchas características para poder llegar a una conclusión a simple vista.
