# %% [markdown]
# <h1> Notebook 1 - Regresión Lineal</h1>

# %% [markdown]
# <p> En este notebook, vamos a implementar un método utilizando el algoritmo de <b>regresión lineal</b> en Python. El objetivo es poder describir este algoritmo y poder re-utilizarlo para resolver problemas de clasificación simple.</p>

# %% [markdown]
# <h2> 1. Definición </h2>
# <p> El algoritmo de <b>regresión lineal</b> es un algortimo de aprendizaje supervisado, de tipo <b>regresión</b>. Los algoritmos de regresión permiten de predecir <b> variables <u>continuas</u></b> a partir de una variable (este caso, hablamos de regresión lineal simple) o varias variables (regresión lineal múltiple).</p>
#
# <p>Por ejemplo, predecir el precio de una casa según la superficie de la casa, su ubicación y/o el tipo de material utilizado, es típicamente un problema de regresión.</p>
#
# <p> En otros terminos, la <b>regresión lineal</b> consiste en encontrar una recta, un plano o un hiperplano que aproxima la distribución de un conjunto de puntos. Detallamos esta idea a continuación con ejemplos e implementación en Python. </p>

# %% [markdown]
# <h2> 2. Implementación de una Regresión Lineal simple </h2>
#
# <p>Consideremos el <b>problema siguiente</b>:</p>
# <p>Usted es el jefe de una empresa de <i>FoodTrucks</i> y busca una nueva ciudad dónde implementar un nuevo punto de venta. Su empresa ya tiene camiones en distintas ciudades y tiene a su disposición los datos indicandos el beneficio realizado en cada ciudad. Usted desea utilizar estos datos para estimar qué beneficio van a realizar según la ciudad escogida.</p>
#
# <p> Este problema es de tipo <b>supervisado</b> porque conocemos cuál es el tipo de variable que queremos predecir:</p>
#  - Y: la variable que queremos predecir (<i>volumen de negocio</i>),<br>
#  - X: la variable explicativa (<i>tamaño de la ciudad</i>)

# %%
#Nuestros datos son al formato CSV y tienen 2 columnas: la populación de la ciudad (por 10000 personas) 
#y el beneficio realizado por la empresa en este ciudad
import pandas as pd
df = pd.read_csv("nb1-dataset1.csv")
df.head()
# Out:
#    Population (10000 pers.)  Beneficio (10K$)
# 0                    6.1101           17.5920
# 1                    5.5277            9.1302
# 2                    8.5186           13.6620
# 3                    7.0032           11.8540
# 4                    5.8598            6.8233

# %%
#selección de la primera columna de nuestro dataset (tamaño de la populacion)
X = df.iloc[0:len(df),0]
#selección de la segunda columna de nuestro dataset (volumen de negocio)
Y = df.iloc[0:len(df),1]

# %%
#Visualización de los datos
import matplotlib.pyplot as plt

axes = plt.axes()
axes.grid()
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# Para aprender un modelo predictivo basado en una regresión lineal, vamos a utilizar la librería Python ScyPy (una librería python open-source para las matemáticas: <a href="https://www.scipy.org/">SciPy</a>).

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
print("slope:{0}\nintercept:{1}".format(slope,intercept))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c075221ab301> in <module>()
#       1 from scipy import stats
#       2
# ----> 3 slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
#       4 print("slope:{0}\nintercept:".format(slope))
#
# ~/.anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#      91
#      92     # average sum of squares:
# ---> 93     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#      94     r_num = ssxym
#      95     r_den = np.sqrt(ssxm * ssym)
#
# ~/.anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    3042         if not rowvar and y.shape[0] != 1:
#    3043             y = y.T
# -> 3044         X = np.concatenate((X, y), axis=0)
#    3045
#    3046     if ddof is None:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %% [markdown]
# <b>Preguntas</b>:
# - ¿Qué hizó la función 'linregress'? <br>
# **resp:** Retorna los parámetros para la recta que se adapta a los datos</br>
# - ¿A qué corresponden las variables 'slope' e 'intercept'? <br>
# **resp:** *slope*: pendiente de la recta, *intercept*: intercepto de la recta con el eje Y</br>
# - ¿A qué corresponden las otras variables?<br>
# **resp:**<br>*r_value*: Coeficiente de correlación<br>*p_value*: Sirve para aceptar o rechazar la hipótesis<br>*std_err*: Error estándar del gradiente estimado </br>

# %%
#Definemos una función que predice 'y' (variable de output), a partir de 'x' (variable de input)  
def predict(x):
   return slope * x + intercept

# %%
#Visualizemos el modelo aprendido por el algoritmo de Regresión Lineal
fitLine = predict(X)
axes = plt.axes()
axes.grid()
plt.scatter(X,Y)
plt.plot(X, fitLine, c='r')
plt.show()

# %% [markdown]
# <p>Según este modelo, ¿cuál sería el beneficio esperado si la ciudad en la cual pensamos instalar un <a>FoodTruck</a> tiene 127.000 habitantes?</p> (pueden utilizar la función "predict()" que definimos anteriormente).

# %%
predict(127000/10000)
# Out:
# 11.255746402895989

# %% [markdown]
# <b>Preguntas</b>:
# - ¿Cómo saber qué tan correcto es nuestro modelo?<br>
# **resp**: r_value debe ser muy cercano a 1.
# - ¿Qué deberiamos hacer para medir la calidad predictiva de nuestro modelo?<br>
# **resp**: Entregarle un dataset amplio y entrenarlo.

# %% [markdown]
# <h2> 3. Regresión lineal múltiple </h2>

# %% [markdown]
# En general, no es siempre posible predecir una variable a partir de una sola variable explicativa. A menudo, se necesita varias variables. En este caso, hablamos de <i>Multivariate Regresion</i>.

# %% [markdown]
# <b>Problema</b>:
# <p>Supongamos que usted quiere vender su casa y buscar cuál podría ser un buen precio para venderla. Tienen a su disposición un dataset que indica el precio de venta de varias casas de su región y de 2 otras variables:</p>
# - la superficie de la casa, <br>
# - el número de habitaciones.

# %%
import pandas as pd
df2 = pd.read_csv("nb1-dataset2.csv")
#print(df2.head())
df2.head()
# Out:
#    Superficie  Numero_habitaciones  Precio
# 0        2104                    3  399900
# 1        1600                    3  329900
# 2        2400                    3  369000
# 3        1416                    2  232000
# 4        3000                    4  539900

# %% [markdown]
# Luego, tenemos que diferenciar las variables predictivas X (Superficie, Numero de habitaciones) y la variable objetivo Y (Precio).

# %%
# Variable objetivo
Y = df2["Precio"]
# Variables predictivas (o explicativas)
X = df2[['Superficie','Numero_habitaciones']]

# %%
#http://www.uach.cl/
#Visualizemos los datos en un espacio en 3 dimensiones
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

    
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1,2,1, projection='3d')
ax.scatter(df2["Superficie"], df2["Numero_habitaciones"], df2["Precio"], c='r', marker='^')
 
ax.set_xlabel('Superficie')
ax.set_ylabel('Numero_habitaciones')
ax.set_zlabel('Precio')
 
plt.show()

# %% [markdown]
# Para poder utilizar el algoritmo Multivariate Regresion, es necesario realizar una etapa de normalización de las variables, para darles un valor entre -1 y 1. La librería Python Scikit-learn permite realizar este proceso.

# %%
from sklearn.preprocessing import StandardScaler
 
scale = StandardScaler()
X_scaled = scale.fit_transform(X[['Superficie', 'Numero_habitaciones']].as_matrix())

#X_scaled = scale.fit_transform(X[['Superficie', 'Numero_habitaciones']].values)
# Out:
# /home/fr4j4/.anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /home/fr4j4/.anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# Entre los algoritmos de Regresión Múltiples, existe el método <i>Ordinary Least Squares</i> (OLS). OLS es un método de optimización que busca minimizar la suma de las diferencias observadas entre las predicciones del modelo y los datos de entrenamiento. Con el paquete 'statsmodels', se puede entrenar un modelo OLS y obtener un resumen del modelo:

# %%
import statsmodels.api as sm

est = sm.OLS(Y, X).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Precio   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     631.4
# Date:                Thu, 06 Sep 2018   Prob (F-statistic):           1.19e-33
# Time:                        11:55:29   Log-Likelihood:                -589.11
# No. Observations:                  47   AIC:                             1182.
# Df Residuals:                      45   BIC:                             1186.
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Superficie            140.8611     15.355      9.174      0.000     109.935     171.788
# Numero_habitaciones  1.698e+04   1.01e+04      1.676      0.101   -3424.632    3.74e+04
# ==============================================================================
# Omnibus:                        2.046   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.359   Jarque-Bera (JB):                1.215
# Skew:                           0.354   Prob(JB):                        0.545
# Kurtosis:                       3.346   Cond. No.                     2.17e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# La variable 'coef' nos indica cuál es el factor de ponderación de cada variable predictiva. Podemos entonces construir nuestra funcion de predicción:

# %%
def predict_price_of_house(Superficie, Numero_habitaciones):
    return 140.8611 * Superficie + 1.698e+04 * Numero_habitaciones

# %%
#Visualización del modelo obtenido

import matplotlib.pyplot as plt

def predict_all(lst_sizes, lst_nb_rooms):
    predicted_prices = []
    for n in range(0, len(Y)):
        predicted_prices.append(predict_price_of_house(lst_sizes[n], lst_nb_rooms[n]))
    return predicted_prices

    
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1,2,1, projection='3d')
 
ax.plot_trisurf(df2["Superficie"], df2["Numero_habitaciones"], predict_all(df2["Superficie"], df2["Numero_habitaciones"]))
                   
plt.show()

# %%
print(predict_price_of_house(4500,5))
# Out:
# 718774.95

# %% [markdown]
# ## <b>Preguntas:</b>
# - ¿Cuál es el principal limite de los modelos predictivos lineales?<br>
# **resp**:<br>
#     - Cuando la relación entre variables no es lineal, este modelo no sirve.
#     - Que los errores de las variables explicativas deben ser excluyentes y el error total debe ser igual a la suma de estos errores.
# - ¿Qué es la Regresión Polinomial? ¿La Regresión Lineal es una Regresión Polinomial?<br>
# **resp**:

# %% [markdown]
# <h2> 3. Trabajo práctico </h2>

# %% [markdown]
# <b>Problema</b>:
#
# <p>Tenemos a disposición un dataset con 1338 observaciones (filas) y 7 características (columnas): edad, genero, bmi (body mass index), número de niños, si es fumadora o no, su región y sus gastos en salud.</p>
#
# <b>Pregunta</b>:
# - Entrenar un modelo predictivo que estima los gastos de salud de un hombre de 55 años, sin niño, teniendo un bmi de 42.6, fumador.
# - Desde un punto de vista del emprendimiento, ¿qué podría ser el valor añadido de este tipo de modelo predictivo? a quién podría servir?
# - Desde un punto de vista científico y ético, ¿qué críticas podría emitir?

# %%
import statsmodels.api as sm
import pandas as pd

dataframe=pd.read_csv('nb1-insurance.csv')
dataframe["smoker"]=dataframe["smoker"].map({"yes":1,"no":0}) #cambiar yes por 1 y no por 0

men=dataframe.query("sex == 'male'")
women=dataframe.query("sex == 'female'")

Y_men=men["expenses"]
X_men=men[["age","children","bmi","smoker"]]

Y_women=women["expenses"]
X_women=women[["age","children","bmi","smoker"]]

est_men = sm.OLS(Y_men, X_men).fit()
est_women = sm.OLS(Y_women, X_women).fit()

# %%
est_men.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     1293.
# Date:                Thu, 06 Sep 2018   Prob (F-statistic):          7.52e-314
# Time:                        11:55:30   Log-Likelihood:                -6889.9
# No. Observations:                 676   AIC:                         1.379e+04
# Df Residuals:                     672   BIC:                         1.381e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age          197.6542     16.526     11.960      0.000     165.205     230.104
# children     199.9593    202.224      0.989      0.323    -197.108     597.026
# bmi           21.0614     22.683      0.929      0.353     -23.477      65.599
# smoker      2.454e+04    587.808     41.751      0.000    2.34e+04    2.57e+04
# ==============================================================================
# Omnibus:                       92.424   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              184.063
# Skew:                           0.797   Prob(JB):                     1.07e-40
# Kurtosis:                       4.999   Cond. No.                         121.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
est_women.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     991.6
# Date:                Thu, 06 Sep 2018   Prob (F-statistic):          6.97e-277
# Time:                        11:55:30   Log-Likelihood:                -6733.9
# No. Observations:                 662   AIC:                         1.348e+04
# Df Residuals:                     658   BIC:                         1.349e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age          199.3445     16.224     12.287      0.000     167.488     231.201
# children     260.8981    206.622      1.263      0.207    -144.820     666.616
# bmi           32.7270     22.347      1.464      0.144     -11.154      76.608
# smoker      2.175e+04    646.091     33.664      0.000    2.05e+04     2.3e+04
# ==============================================================================
# Omnibus:                      209.004   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              592.400
# Skew:                           1.566   Prob(JB):                    2.30e-129
# Kurtosis:                       6.416   Cond. No.                         134.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def predict_men(age,children,bmi,smoker):
    return age*197.6542 + children*199.9593 + bmi*21.0614 +smoker*2.454e+04

def predict_women(age,children,bmi,smoker):
    return age*199.3445 + children*260.8981 + bmi*32.7270 +smoker*2.175e+04

# %%
gastos_men = predict_men(55,0,42.6,1)
gastos_women = predict_women(55,0,42.6,1)

# %%
gastos_men
# Out:
# 36308.19664

# %%
gastos_women
# Out:
# 34108.1177

# %%
gastos_men - gastos_women  #lo que gastaria el hombre con respecto a la mujer
# Out:
# 2200.0789399999994

# %% [markdown]
# - Entrenar un modelo predictivo que estima los gastos de salud de un hombre de 55 años, sin niño, teniendo un bmi de 42.6, fumador.<br>
# **hecho**
# - Desde un punto de vista del emprendimiento, ¿qué podría ser el valor añadido de este tipo de modelo predictivo? a quién podría servir?<br>
# **resp**: Podría servirle a empresas relacionadas con el tema de estudios que tengna que ver con el modelo. Sirve para predecir comportamiento, en este caso de una población. Permite conocer que valores esperar y por lo tanto saber en qué sectores concentrar la atención de estudio.
# - Desde un punto de vista científico y ético, ¿qué críticas podría emitir?<br>
# **resp**: Personalmente creo que estos modelos son magnificos desde el punto de vista de que la matemática nos ayuda a facilitar el mundo en el que vivimos, nos ayuda en el día a día minimizando el esfuerzo necesario para realizar ciertas tareas. Desde el punto de vista ético me parece un poco delicado este tema, ya que toda esta información podría invadir la privacidad de las personas involucradas, o podría ser utilizada para sacar más provecho de ellas sin que puedan hacer nada al respecto.
